# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
len(text1)
# Out:
# 260819

# %%
type(text1) #text 인덱싱 가능
# Out:
# nltk.text.Text

# %%
text1[:100]  #리스트형식으로 보여주고 있따
# Out:
# ['[',
#  'Moby',
#  'Dick',
#  'by',
#  'Herman',
#  'Melville',
#  '1851',
#  ']',
#  'ETYMOLOGY',
#  '.',
#  '(',
#  'Supplied',
#  'by',
#  'a',
#  'Late',
#  'Consumptive',
#  'Usher',
#  'to',
#  'a',
#  'Grammar',
#  'School',
#  ')',
#  'The',
#  'pale',
#  'Usher',
#  '--',
#  'threadbare',
#  'in',
#  'coat',
#  ',',
#  'heart',
#  ',',
#  'body',
#  ',',
#  'and',
#  'brain',
#  ';',
#  'I',
#  'see',
#  'him',
#  'now',
#  '.',
#  'He',
#  'was',
#  'ever',
#  'dusting',
#  'his',
#  'old',
#  'lexicons',
#  'and',
#  'grammars',
#  ',',
#  'with',
#  'a',
#  'queer',
#  'handkerchief',
#  ',',
#  'mockingly',
#  'embellished',
#  'with',
#  'all',
#  'the',
#  'gay',
#  'flags',
#  'of',
#  'all',
#  'the',
#  'known',
#  'nations',
#  'of',
#  'the',
#  'world',
#  '.',
#  'He',
#  'loved',
#  'to',
#  'dust',
#  'his',
#  'old',
#  'grammars',
#  ';',
#  'it',
#  'somehow',
#  'mildly',
#  'reminded',
#  'him',
#  'of',
#  'his',
#  'mortality',
#  '.',
#  '"',
# ...

# %%
text2[:200]
# Out:
# ['[',
#  'Sense',
#  'and',
#  'Sensibility',
#  'by',
#  'Jane',
#  'Austen',
#  '1811',
#  ']',
#  'CHAPTER',
#  '1',
#  'The',
#  'family',
#  'of',
#  'Dashwood',
#  'had',
#  'long',
#  'been',
#  'settled',
#  'in',
#  'Sussex',
#  '.',
#  'Their',
#  'estate',
#  'was',
#  'large',
#  ',',
#  'and',
#  'their',
#  'residence',
#  'was',
#  'at',
#  'Norland',
#  'Park',
#  ',',
#  'in',
#  'the',
#  'centre',
#  'of',
#  'their',
#  'property',
#  ',',
#  'where',
#  ',',
#  'for',
#  'many',
#  'generations',
#  ',',
#  'they',
#  'had',
#  'lived',
#  'in',
#  'so',
#  'respectable',
#  'a',
#  'manner',
#  'as',
#  'to',
#  'engage',
#  'the',
#  'general',
#  'good',
#  'opinion',
#  'of',
#  'their',
#  'surrounding',
#  'acquaintance',
#  '.',
#  'The',
#  'late',
#  'owner',
#  'of',
#  'this',
#  'estate',
#  'was',
#  'a',
#  'single',
#  'man',
#  ',',
#  'who',
#  'lived',
#  'to',
#  'a',
#  'very',
#  'advanced',
#  'age',
#  ',',
#  'and',
#  'who',
#  'for',
# ...

# %% [markdown]
# ## 1.3 Searchint Text
#
# A concordance view shows us every occurrence of a given word, together with some context. Here we look up the word monstrous in Moby Dick by entering text1 followed by a period, then the term concordance, and then placing "monstrous" in parentheses:

# %%
text2.concordance("sensibility") #인근에 있는 단어 찾기
# Out:
# Displaying 10 of 10 matches:
# [ Sense and Sensibility by Jane Austen 1811 ] CHAPTER 1 T
# rn , the excess of her sister ' s sensibility ; but by Mrs . Dashwood it was va
# , to hear him read with so little sensibility . Mama , the more I know of the w
# erable ; and he read with all the sensibility and spirit which Edward had unfor
# the ridicule so justly annexed to sensibility . Elinor was obliged , though unw
#  at consolation from either . Her sensibility was potent enough ! When breakfas
# her on the delicacies of a strong sensibility , and the graces of a polished ma
#  a strong impulse of affectionate sensibility , she moved after a moment , to h
# proof of her ' s , but by his own sensibility . " We may treat it as a joke ,"
# oor Fanny had suffered agonies of sensibility -- and he considered the existenc

# %%
#sorted(text4[:100])
sorted(set(text4[:100]))  #set하면 중복 사라진다
# Out:
# [',',
#  '-',
#  '.',
#  '14th',
#  ':',
#  'Among',
#  'Citizens',
#  'Country',
#  'Fellow',
#  'House',
#  'I',
#  'On',
#  'Representatives',
#  'Senate',
#  'a',
#  'an',
#  'and',
#  'anxieties',
#  'as',
#  'but',
#  'by',
#  'can',
#  'chosen',
#  'could',
#  'day',
#  'decision',
#  'event',
#  'filled',
#  'flattering',
#  'fondest',
#  'from',
#  'greater',
#  'had',
#  'hand',
#  'have',
#  'hear',
#  'hopes',
#  'immutable',
#  'in',
#  'incident',
#  'life',
#  'love',
#  'me',
#  'month',
#  'my',
#  'never',
#  'no',
#  'notification',
#  'of',
#  'on',
#  'one',
#  'order',
#  'predilection',
#  'present',
#  'received',
#  'retreat',
#  'summoned',
#  'than',
#  'that',
#  'the',
#  'to',
#  'transmitted',
#  'veneration',
#  'vicissitudes',
#  'voice',
#  'was',
#  'which',
#  'whose',
#  'with',
#  'your']

# %%
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America"])

# %% [markdown]
# #### 취임사에 강조한것을 해석

# %%
wordList = []
for i in range(3):
    word = input("Enter a word: ")
    wordList.append(word)
# Out:
# Enter a word: love
# Enter a word: murder
# Enter a word: trlal

# %%
texts = [text1, text2, text3, text4, text5, text6, text7, text8, text9]
for text in texts:
    print(text)
    text.dispersion_plot(wordList)
# Out:
# <Text: Moby Dick by Herman Melville 1851>
# <Text: Sense and Sensibility by Jane Austen 1811>
# <Text: The Book of Genesis>
# <Text: Inaugural Address Corpus>
# <Text: Chat Corpus>
# <Text: Monty Python and the Holy Grail>
# <Text: Wall Street Journal>
# <Text: Personals Corpus>
# <Text: The Man Who Was Thursday by G . K . Chesterton 1908>

# %% [markdown]
# ##  입력받은 단어가 text에 포함되는것들 표시

# %%
len(text4)
# Out:
# 152901

# %%
len(set(text4))
# Out:
# 10025

# %%
nltk.FreqDist(text1) #텍스트에 포함된 총 단어 토큰 수가 어떻게 되는지 알려준다
# Out:
# FreqDist({',': 18713, 'the': 13721, '.': 6862, 'of': 6536, 'and': 6024, 'a': 4569, 'to': 4542, ';': 4072, 'in': 3916, 'that': 2982, ...})

# %%
x = nltk.FreqDist(text2)

# %%
x.most_common(100)  # 제일 빈도수 높은거부터 100개 노출
# Out:
# [(',', 9397),
#  ('to', 4063),
#  ('.', 3975),
#  ('the', 3861),
#  ('of', 3565),
#  ('and', 3350),
#  ('her', 2436),
#  ('a', 2043),
#  ('I', 2004),
#  ('in', 1904),
#  ('was', 1846),
#  ('it', 1568),
#  ('"', 1506),
#  (';', 1419),
#  ('she', 1333),
#  ('be', 1305),
#  ('that', 1297),
#  ('for', 1234),
#  ('not', 1212),
#  ('as', 1179),
#  ('you', 1037),
#  ('with', 971),
#  ('had', 969),
#  ('his', 941),
#  ('he', 895),
#  ("'", 883),
#  ('have', 807),
#  ('at', 806),
#  ('by', 737),
#  ('is', 728),
#  ('."', 721),
#  ('s', 700),
#  ('Elinor', 684),
#  ('on', 676),
#  ('all', 642),
#  ('him', 633),
#  ('so', 617),
#  ('but', 597),
#  ('which', 592),
#  ('could', 568),
#  ('Marianne', 566),
#  ('my', 551),
#  ('Mrs', 530),
#  ('from', 527),
#  ('would', 507),
#  ('very', 492),
#  ('no', 488),
#  ('their', 463),
#  ('them', 462),
#  ('--', 461),
#  ('been', 440),
#  ('were', 437),
#  ('me', 433),
#  ('they', 428),
#  ('more', 406),
#  ('said', 397),
#  (',"', 396),
#  ('any', 389),
# ...

# %%
x['are']  #딕셔녀리 형태이다
# Out:
# 224

# %%
Y =set(text1)

# %%
len(Y)
# Out:
# 19317

# %%
long_words = [w for w in Y if len(w) > 15] #15이상인 단어를 찾아 출력

# %%
long_words
# Out:
# ['superstitiousness',
#  'uncompromisedness',
#  'uninterpenetratingly',
#  'circumnavigating',
#  'physiognomically',
#  'hermaphroditical',
#  'characteristically',
#  'apprehensiveness',
#  'circumnavigations',
#  'responsibilities',
#  'Physiognomically',
#  'indiscriminately',
#  'irresistibleness',
#  'preternaturalness',
#  'indispensableness',
#  'circumnavigation',
#  'simultaneousness',
#  'supernaturalness',
#  'subterraneousness',
#  'uncomfortableness',
#  'CIRCUMNAVIGATION',
#  'cannibalistically',
#  'undiscriminating',
#  'comprehensiveness']

# %%
fdist5 =nltk.FreqDist(text5) #빈도수

# %%
[w for w in set(text5) if len(w) > 8 and fdist5[w] > 8]  #단어길이 8개, 빈도수 8회
# Out:
# ['seriously',
#  'listening',
#  'cute.-ass',
#  '((((((((((',
#  '#talkcity_adults',
#  '#14-19teens',
#  'something']

# %% [markdown]
# ## 3.3 collocations and bigrams 쌍으로 표현

# %%
mySentence = ['time', 'flise', "like", "an", "arrow"]

# %%
list(nltk.ngrams(mySentence, 3))
# Out:
# [('time', 'flise', 'like'), ('flise', 'like', 'an'), ('like', 'an', 'arrow')]

# %%
list(bigrams(mySentence))
# Out:
# [('time', 'flise'), ('flise', 'like'), ('like', 'an'), ('an', 'arrow')]

# %%
nltk.bigrams(mySentence)
# Out:
# <generator object bigrams at 0x00000252A4DD26C0>

# %%
list(nltk.bigrams(mySentence))
# Out:
# [('time', 'flise'), ('flise', 'like'), ('like', 'an'), ('an', 'arrow')]

# %%
print('; '.join(text1.collocation_list()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 print('; '.join(text1.collocation_list()))
#
# TypeError: sequence item 0: expected str instance, tuple found

# %%
[len(w) for w in mySentence]
# Out:
# [4, 5, 4, 2, 5]

# %%
mySentence
# Out:
# ['time', 'flise', 'like', 'an', 'arrow']

# %%
[len(w) for w in text1]
# Out:
# [1,
#  4,
#  4,
#  2,
#  6,
#  8,
#  4,
#  1,
#  9,
#  1,
#  1,
#  8,
#  2,
#  1,
#  4,
#  11,
#  5,
#  2,
#  1,
#  7,
#  6,
#  1,
#  3,
#  4,
#  5,
#  2,
#  10,
#  2,
#  4,
#  1,
#  5,
#  1,
#  4,
#  1,
#  3,
#  5,
#  1,
#  1,
#  3,
#  3,
#  3,
#  1,
#  2,
#  3,
#  4,
#  7,
#  3,
#  3,
#  8,
#  3,
#  8,
#  1,
#  4,
#  1,
#  5,
#  12,
#  1,
#  9,
#  11,
#  4,
#  3,
#  3,
#  3,
#  5,
#  2,
#  3,
#  3,
#  5,
#  7,
#  2,
#  3,
#  5,
#  1,
#  2,
#  5,
#  2,
#  4,
#  3,
#  3,
#  8,
#  1,
#  2,
#  7,
#  6,
#  8,
#  3,
#  2,
#  3,
#  9,
#  1,
#  1,
#  5,
#  3,
#  4,
#  2,
#  4,
#  2,
#  6,
#  6,
#  1,
#  3,
#  2,
#  5,
#  4,
#  2,
#  4,
#  4,
#  1,
#  5,
#  1,
#  4,
#  2,
#  2,
#  2,
#  6,
#  2,
#  3,
#  6,
#  7,
#  3,
#  1,
#  7,
#  9,
#  1,
#  3,
#  6,
#  1,
#  1,
#  5,
#  6,
#  5,
#  6,
#  3,
#  13,
#  2,
#  3,
#  4,
#  1,
#  3,
#  7,
#  4,
#  5,
#  2,
#  3,
#  4,
#  2,
#  2,
#  8,
#  1,
#  5,
#  1,
#  3,
#  2,
#  1,
#  3,
#  3,
#  1,
#  4,
#  1,
#  4,
#  6,
#  2,
#  5,
#  4,
#  9,
# ...
